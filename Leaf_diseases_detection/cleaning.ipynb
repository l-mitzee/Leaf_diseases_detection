# %%
# libraries
import numpy as np # used for handling numbers
import pandas as pd # used for handling the dataset

# %%
dataset = pd.read_csv('output_file.csv')

# %%
dataset.head()
# Out:
#                               file_name  file_size  caption  public_domain
# 0  a28ecaa0140dde95cadbdc33f8ba8f21.jpg     246226      NaN            NaN  \
# 1  a28ecaa0140dde95cadbdc33f8ba8f21.jpg     246226      NaN            NaN
# 2     Anthracnose-on-Mustard-Greens.jpg     105618      NaN            NaN
# 3     Anthracnose-on-Mustard-Greens.jpg     105618      NaN            NaN
# 4                          bac-leaf.jpg     222215      NaN            NaN
#
#    image_url  region_count  region_id shape_name    cx   cy       rx       ry
# 0        NaN             2          0    ellipse   798  726  274.301  249.351  \
# 1        NaN             2          1     circle   668  264      NaN      NaN
# 2        NaN             2          0    ellipse   588  404  138.991  235.943
# 3        NaN             2          1     circle  1018  458      NaN      NaN
# 4        NaN             2          0    ellipse   838  248   97.733  208.563
#
#       r  theta       type                                        description
# 0   NaN  0.011     Normal                                             Normal  \
# 1  94.0    NaN     Normal                                             Normal
# 2   NaN  3.088  Leaf spot  Leaf spots (other names: anthracnose, scab, le...
# 3  69.0    NaN  Leaf spot  Leaf spots (other names: anthracnose, scab, le...
# 4   NaN -0.025      Rusts  Rusts often produce spots similar to leaf spot...
#
#        image_quality
# 0  Good_Illumination
# 1     Blurred region
# 2  Good_Illumination
# 3  Good_Illumination
# 4  Good_Illumination

# %%
print("missing values")
print(dataset.isnull().sum())
print("")
# Out:
# missing values
# file_name         0
# file_size         0
# caption          73
# public_domain    73
# image_url        73
# region_count      0
# region_id         0
# shape_name        0
# cx                0
# cy                0
# rx               13
# ry               13
# r                60
# theta            13
# type              0
# description       0
# image_quality     0
# dtype: int64

# %%
dataset.fillna(value = 0,
          inplace = True)

# %%
print(dataset.isnull().sum())
# Out:
# file_name        0
# file_size        0
# caption          0
# public_domain    0
# image_url        0
# region_count     0
# region_id        0
# shape_name       0
# cx               0
# cy               0
# rx               0
# ry               0
# r                0
# theta            0
# type             0
# description      0
# image_quality    0
# dtype: int64

# %%
dataset.head()
# Out:
#                               file_name  file_size  caption  public_domain
# 0  a28ecaa0140dde95cadbdc33f8ba8f21.jpg     246226      0.0            0.0  \
# 1  a28ecaa0140dde95cadbdc33f8ba8f21.jpg     246226      0.0            0.0
# 2     Anthracnose-on-Mustard-Greens.jpg     105618      0.0            0.0
# 3     Anthracnose-on-Mustard-Greens.jpg     105618      0.0            0.0
# 4                          bac-leaf.jpg     222215      0.0            0.0
#
#    image_url  region_count  region_id shape_name    cx   cy       rx       ry
# 0        0.0             2          0    ellipse   798  726  274.301  249.351  \
# 1        0.0             2          1     circle   668  264    0.000    0.000
# 2        0.0             2          0    ellipse   588  404  138.991  235.943
# 3        0.0             2          1     circle  1018  458    0.000    0.000
# 4        0.0             2          0    ellipse   838  248   97.733  208.563
#
#       r  theta       type                                        description
# 0   0.0  0.011     Normal                                             Normal  \
# 1  94.0  0.000     Normal                                             Normal
# 2   0.0  3.088  Leaf spot  Leaf spots (other names: anthracnose, scab, le...
# 3  69.0  0.000  Leaf spot  Leaf spots (other names: anthracnose, scab, le...
# 4   0.0 -0.025      Rusts  Rusts often produce spots similar to leaf spot...
#
#        image_quality
# 0  Good_Illumination
# 1     Blurred region
# 2  Good_Illumination
# 3  Good_Illumination
# 4  Good_Illumination

# %%
dataset.to_csv('leaf_defect.csv')
